# %% [markdown]
# Importing Libraries

# %%
# 1️⃣ Import Required Libraries
import pandas as pd
import re
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from transformers import DistilBertTokenizer, TFDistilBertModel
import nltk
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import joblib

# %%
# 2️⃣ Load Dataset
df = pd.read_csv('/content/IMDB Dataset.csv', encoding='ISO-8859-1', on_bad_lines='skip')
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
# 3️⃣ Understand Dataset
df.nunique() # Get number of unique values
# Out:
# review       49582
# sentiment        2
# dtype: int64

# %%
# Checking whether Data is imbalance or not
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %% [markdown]
# Processing the Data

# %%
# 4️⃣ Text Preprocessing
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
stemmer = nltk.PorterStemmer()

def preprocess(review):
    review = review.lower()  # Convert to lowercase
    review = re.sub('[^a-z]', ' ', review)  # Remove non-alphabetic characters
    words = [stemmer.stem(word) for word in review.split() if word not in stopwords]  # Remove stopwords & stem
    return ' '.join(words)

df['processed_review'] = df['review'].apply(preprocess)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# 5️⃣ Load TensorFlow-based DistilBERT Model & Tokenizer
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
bert_model = TFDistilBertModel.from_pretrained('distilbert-base-uncased')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFDistilBertModel: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing TFDistilBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFDistilBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertModel for predictions without further training.

# %%
# 6️⃣ Function to Get BERT Embeddings (Batch Processing for Efficiency)
def get_bert_embeddings_batch(texts, batch_size=16):
    embeddings = []

    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        inputs = tokenizer(batch_texts, return_tensors='tf', truncation=True, padding=True, max_length=128)

        outputs = bert_model(inputs)
        batch_embeddings = outputs.last_hidden_state[:, 0, :].numpy()  # Extract [CLS] token embedding
        embeddings.append(batch_embeddings)

    return np.vstack(embeddings)  # Stack all embeddings into a single numpy array

# %%
# 7️⃣ Convert Reviews to BERT Embeddings
processed_reviews = df['processed_review'].tolist()
X_bert = get_bert_embeddings_batch(processed_reviews, batch_size=16)

# %%
# 8️⃣ Prepare Labels for Training (Binary Classification)
y = df['sentiment'].map({'positive': 1, 'negative': 0}).astype(np.int8)  # Only 0 & 1

# %%
# 9️⃣ Split Data into Training & Test Sets
X_train, X_test, y_train, y_test = train_test_split(X_bert, y, test_size=0.2, random_state=42)

# %%
# 🔟 Define Deep Learning Model (Binary Classification)
model = Sequential([
    Dense(128, activation='relu', input_shape=(768,)),  # BERT output size = 768
    Dropout(0.3),
    Dense(1, activation='sigmoid')  # 1 neuron for binary classification
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 1️⃣1️⃣ Train Deep Learning Model
model.fit(X_train, y_train, epochs=53, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.6900 - loss: 0.5789 - val_accuracy: 0.7544 - val_loss: 0.5083
# Epoch 2/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7485 - loss: 0.5100 - val_accuracy: 0.7600 - val_loss: 0.5018
# Epoch 3/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7551 - loss: 0.5000 - val_accuracy: 0.7624 - val_loss: 0.4944
# Epoch 4/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7554 - loss: 0.4922 - val_accuracy: 0.7635 - val_loss: 0.4892
# Epoch 5/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7647 - loss: 0.4854 - val_accuracy: 0.7635 - val_loss: 0.4875
# Epoch 6/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7629 - loss: 0.4887 - val_accuracy: 0.7615 - val_loss: 0.4866
# Epoch 7/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7663 - loss: 0.4784 - val_accuracy: 0.7636 - val_loss: 0.4868
# Epoch 8/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7653 - loss: 0.4789 - val_accuracy: 0.7588 - val_loss: 0.4893
# Epoch 9/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7731 - loss: 0.4686 - val_accuracy: 0.7609 - val_loss: 0.4897
# Epoch 10/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7709 - loss: 0.4743 - val_accuracy: 0.7657 - val_loss: 0.4791
# Epoch 11/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7746 - loss: 0.4659 - val_accuracy: 0.7690 - val_loss: 0.4775
# Epoch 12/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7729 - loss: 0.4717 - val_accuracy: 0.7690 - val_loss: 0.4778
# Epoch 13/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7723 - loss: 0.4688 - val_accuracy: 0.7690 - val_loss: 0.4766
# Epoch 14/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7774 - loss: 0.4577 - val_accuracy: 0.7573 - val_loss: 0.5011
# Epoch 15/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7756 - loss: 0.4583 - val_accuracy: 0.7729 - val_loss: 0.4743
# Epoch 16/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7786 - loss: 0.4611 - val_accuracy: 0.7707 - val_loss: 0.4728
# Epoch 17/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7856 - loss: 0.4487 - val_accuracy: 0.7513 - val_loss: 0.4939
# Epoch 18/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7847 - loss: 0.4538 - val_accuracy: 0.7713 - val_loss: 0.4716
# Epoch 19/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7823 - loss: 0.4542 - val_accuracy: 0.7491 - val_loss: 0.4978
# Epoch 20/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7870 - loss: 0.4474 - val_accuracy: 0.7745 - val_loss: 0.4722
# Epoch 21/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7881 - loss: 0.4483 - val_accuracy: 0.7717 - val_loss: 0.4732
# Epoch 22/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7895 - loss: 0.4479 - val_accuracy: 0.7760 - val_loss: 0.4659
# Epoch 23/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7893 - loss: 0.4430 - val_accuracy: 0.7697 - val_loss: 0.4852
# Epoch 24/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7872 - loss: 0.4446 - val_accuracy: 0.7765 - val_loss: 0.4712
# Epoch 25/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7921 - loss: 0.4422 - val_accuracy: 0.7734 - val_loss: 0.4718
# Epoch 26/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7902 - loss: 0.4416 - val_accuracy: 0.7741 - val_loss: 0.4774
# Epoch 27/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7917 - loss: 0.4367 - val_accuracy: 0.7642 - val_loss: 0.4852
# Epoch 28/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7969 - loss: 0.4304 - val_accuracy: 0.7755 - val_loss: 0.4678
# Epoch 29/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7914 - loss: 0.4398 - val_accuracy: 0.7747 - val_loss: 0.4647
# Epoch 30/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7974 - loss: 0.4347 - val_accuracy: 0.7774 - val_loss: 0.4696
# Epoch 31/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7944 - loss: 0.4307 - val_accuracy: 0.7745 - val_loss: 0.4685
# Epoch 32/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8003 - loss: 0.4265 - val_accuracy: 0.7690 - val_loss: 0.4808
# Epoch 33/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8040 - loss: 0.4260 - val_accuracy: 0.7757 - val_loss: 0.4685
# Epoch 34/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7973 - loss: 0.4288 - val_accuracy: 0.7757 - val_loss: 0.4629
# Epoch 35/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7997 - loss: 0.4262 - val_accuracy: 0.7691 - val_loss: 0.4701
# Epoch 36/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7998 - loss: 0.4282 - val_accuracy: 0.7691 - val_loss: 0.4723
# Epoch 37/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7999 - loss: 0.4254 - val_accuracy: 0.7596 - val_loss: 0.4967
# Epoch 38/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8032 - loss: 0.4199 - val_accuracy: 0.7732 - val_loss: 0.4713
# Epoch 39/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8022 - loss: 0.4214 - val_accuracy: 0.7765 - val_loss: 0.4723
# Epoch 40/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8027 - loss: 0.4221 - val_accuracy: 0.7770 - val_loss: 0.4687
# Epoch 41/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8048 - loss: 0.4137 - val_accuracy: 0.7715 - val_loss: 0.4682
# Epoch 42/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8106 - loss: 0.4088 - val_accuracy: 0.7669 - val_loss: 0.4789
# Epoch 43/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8077 - loss: 0.4098 - val_accuracy: 0.7745 - val_loss: 0.4651
# Epoch 44/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8065 - loss: 0.4100 - val_accuracy: 0.7750 - val_loss: 0.4709
# Epoch 45/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8061 - loss: 0.4104 - val_accuracy: 0.7736 - val_loss: 0.4722
# Epoch 46/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8103 - loss: 0.4086 - val_accuracy: 0.7770 - val_loss: 0.4774
# Epoch 47/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8089 - loss: 0.4079 - val_accuracy: 0.7763 - val_loss: 0.4815
# Epoch 48/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8156 - loss: 0.4037 - val_accuracy: 0.7707 - val_loss: 0.4736
# Epoch 49/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8118 - loss: 0.4025 - val_accuracy: 0.7761 - val_loss: 0.4712
# Epoch 50/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8102 - loss: 0.4058 - val_accuracy: 0.7759 - val_loss: 0.4692
# Epoch 51/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8165 - loss: 0.3986 - val_accuracy: 0.7759 - val_loss: 0.4793
# Epoch 52/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8152 - loss: 0.3995 - val_accuracy: 0.7753 - val_loss: 0.4720
# Epoch 53/53
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8149 - loss: 0.3983 - val_accuracy: 0.7721 - val_loss: 0.5051

# %%
# 1️⃣2️⃣ Train Logistic Regression Model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# 1️⃣3️⃣ Train Random Forest Model
clf_rf = RandomForestClassifier(n_estimators=200, random_state=42)
clf_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
# 1️⃣4️⃣ Train Gradient Boosting
clf_gb = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, subsample=0.8)
clf_gb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(subsample=0.8)

# %%
# 1️⃣5️⃣ Compute Training Accuracy for All Models
y_train_pred_dl = np.argmax(model.predict(X_train), axis=1)  # Deep Learning Model
y_train_pred_lr = clf.predict(X_train)  # Logistic Regression
y_train_pred_gb = clf_gb.predict(X_train)  # Gradient Boosting
y_train_pred_rf = clf_rf.predict(X_train)  # Random Forest (if using)

# Print Training Accuracy for Each Model
print(f"Deep Learning Model Train Accuracy: {accuracy_score(y_train, y_train_pred_dl):.4f}")
print(f"Logistic Regression Train Accuracy: {accuracy_score(y_train, y_train_pred_lr):.4f}")
print(f"Gradient Boosting Train Accuracy: {accuracy_score(y_train, y_train_pred_gb):.4f}")
print(f"Random Forest Train Accuracy: {accuracy_score(y_train, y_train_pred_rf):.4f}")  # If using Random Forest
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Deep Learning Model Train Accuracy: 0.5010
# Logistic Regression Train Accuracy: 0.7904
# Gradient Boosting Train Accuracy: 0.7611
# Random Forest Train Accuracy: 1.0000

# %%
# 1️⃣6️⃣ Predict & Evaluate All Models on Test Data
y_pred_dl = (model.predict(X_test) > 0.5).astype("int32").flatten()
y_pred_lr = clf.predict(X_test)
y_pred_rf = clf_rf.predict(X_test)
y_pred_gb = clf_gb.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# 1️⃣6️⃣ Predict & Evaluate All Models on Test Data
print(f"Deep Learning Model Test Accuracy: {accuracy_score(y_test, y_pred_dl):.4f}")
print(f"Logistic Regression Test Accuracy: {accuracy_score(y_test, y_pred_lr):.4f}")
print(f"Gradient Boosting Test Accuracy: {accuracy_score(y_test, y_pred_gb):.4f}")
print(f"Random Forest Test Accuracy: {accuracy_score(y_test, y_pred_rf):.4f}")
# Out:
# Deep Learning Model Test Accuracy: 0.7786
# Logistic Regression Test Accuracy: 0.7798
# Gradient Boosting Test Accuracy: 0.7389
# Random Forest Test Accuracy: 0.7335

# %%
# 1️⃣7️⃣ Save All Models
model.save('sentiment_dl_model.h5')  # Save Deep Learning Model
joblib.dump(clf, 'sentiment_lr_model.pkl')  # Save Logistic Regression Model
joblib.dump(clf_rf, 'sentiment_rf_model.pkl')  # Save Random Forest Model
joblib.dump(clf_gb, 'sentiment_gb_model.pkl')  # Save Gradient Boosting Model
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['sentiment_gb_model.pkl']

# %%
# 1️⃣8️⃣ Example Predictions on New Data
reviews = ['Pure cinematic magic!', 'This film left me speechless', 'Boring, even with explosions.']
test_embeddings = get_bert_embeddings_batch([preprocess(r) for r in reviews], batch_size=16)
predictions = clf.predict(test_embeddings)
print(predictions)  # Display predictions
# Out:
# [1 0 0]
