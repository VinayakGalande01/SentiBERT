# %% [markdown]
# Importing Libraries

# %%
# 1️⃣ Import Required Libraries
import pandas as pd
import re
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from transformers import DistilBertTokenizer, TFDistilBertModel
import nltk
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
import joblib

# %%
# 2️⃣ Load Dataset
df = pd.read_csv('/content/IMDB Dataset.csv', encoding='ISO-8859-1', on_bad_lines='skip')
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# Processing the Data

# %%
# 3️⃣ Text Preprocessing
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
stemmer = nltk.PorterStemmer()

def preprocess(review):
    review = review.lower()  # Convert to lowercase
    review = re.sub('[^a-z]', ' ', review)  # Remove non-alphabetic characters
    words = [stemmer.stem(word) for word in review.split() if word not in stopwords]  # Remove stopwords & stem
    return ' '.join(words)

df['processed_review'] = df['review'].apply(preprocess)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# # Apply preprocessing to reviews
# nltk.download('stopwords')
# stopwords = nltk.corpus.stopwords.words('english')
# processed_reviews = df['review'].apply(preprocess).tolist()
# y_train = df['sentiment'].map({'positive': 1, 'negative': 0, 'neutral': 2}).astype(np.int8)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-90af4631db31> in <cell line: 0>()
#       2 nltk.download('stopwords')
#       3 stopwords = nltk.corpus.stopwords.words('english')
# ----> 4 processed_reviews = df['review'].apply(preprocess).tolist()
#       5 y_train = df['sentiment'].map({'positive': 1, 'negative': 0, 'neutral': 2}).astype(np.int8)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-5-e4a98a9f7882> in preprocess(review)
#       7     review = review.lower()  # Convert to lowercase
#       8     review = re.sub('[^a-z]', ' ', review)  # Remove non-alphabetic characters
# ----> 9     words = [stemmer.stem(word) for word in review.split() if word not in stopwords]  # Remove stopwords & stem
#      10     return ' '.join(words)
#      11
#
# <ipython-input-5-e4a98a9f7882> in <listcomp>(.0)
#       7     review = review.lower()  # Convert to lowercase
#       8     review = re.sub('[^a-z]', ' ', review)  # Remove non-alphabetic characters
# ----> 9     words = [stemmer.stem(word) for word in review.split() if word not in stopwords]  # Remove stopwords & stem
#      10     return ' '.join(words)
#      11
#
# /usr/local/lib/python3.11/dist-packages/nltk/stem/porter.py in stem(self, word, to_lowercase)
#     672         stem = self._step1b(stem)
#     673         stem = self._step1c(stem)
# --> 674         stem = self._step2(stem)
#     675         stem = self._step3(stem)
#     676         stem = self._step4(stem)
#
# /usr/local/lib/python3.11/dist-packages/nltk/stem/porter.py in _step2(self, word)
#     435         )
#     436
# --> 437     def _step2(self, word):
#     438         """Implements Step 2 from "An algorithm for suffix stripping"
#     439
#
# KeyboardInterrupt:

# %%
# 4️⃣ Load TensorFlow-based DistilBERT Model & Tokenizer
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
bert_model = TFDistilBertModel.from_pretrained('distilbert-base-uncased')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFDistilBertModel: ['vocab_projector.bias', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing TFDistilBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFDistilBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertModel for predictions without further training.

# %%
# 5️⃣ Function to Get BERT Embeddings (Batch Processing for Efficiency)
def get_bert_embeddings_batch(texts, batch_size=16):
    embeddings = []

    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        inputs = tokenizer(batch_texts, return_tensors='tf', truncation=True, padding=True, max_length=128)

        outputs = bert_model(inputs)
        batch_embeddings = outputs.last_hidden_state[:, 0, :].numpy()  # Extract [CLS] token embedding
        embeddings.append(batch_embeddings)

    return np.vstack(embeddings)  # Stack all embeddings into a single numpy array

# %%
# 6️⃣ Convert Reviews to BERT Embeddings
processed_reviews = df['processed_review'].tolist()
X_bert = get_bert_embeddings_batch(processed_reviews, batch_size=16)

# %%
# 7️⃣ Prepare Labels for Training
y = df['sentiment'].map({'positive': 1, 'negative': 0, 'neutral': 2}).astype(np.int8)

# %%
# 8️⃣ Split Data into Training & Test Sets
X_train, X_test, y_train, y_test = train_test_split(X_bert, y, test_size=0.2, random_state=42)

# %%
# 9️⃣ Define Deep Learning Model
model = Sequential([
    Dense(128, activation='relu', input_shape=(768,)),  # BERT output size = 768
    Dropout(0.3),
    Dense(3, activation='softmax')  # 3 classes: Positive, Negative, Neutral
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 🔟 Convert labels to TensorFlow format
y_train_tensor = tf.convert_to_tensor(y_train, dtype=tf.int32)

# %%
# 1️⃣1️⃣ Train Deep Learning Model
model.fit(X_train, y_train_tensor, epochs=65, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8561 - loss: 0.3184 - val_accuracy: 0.7689 - val_loss: 0.5432
# Epoch 2/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8541 - loss: 0.3197 - val_accuracy: 0.7656 - val_loss: 0.5375
# Epoch 3/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8575 - loss: 0.3157 - val_accuracy: 0.7644 - val_loss: 0.5297
# Epoch 4/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8583 - loss: 0.3160 - val_accuracy: 0.7689 - val_loss: 0.5316
# Epoch 5/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8519 - loss: 0.3181 - val_accuracy: 0.7640 - val_loss: 0.5275
# Epoch 6/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8587 - loss: 0.3145 - val_accuracy: 0.7709 - val_loss: 0.5349
# Epoch 7/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8542 - loss: 0.3196 - val_accuracy: 0.7696 - val_loss: 0.5526
# Epoch 8/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8584 - loss: 0.3064 - val_accuracy: 0.7648 - val_loss: 0.5633
# Epoch 9/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8555 - loss: 0.3180 - val_accuracy: 0.7576 - val_loss: 0.5410
# Epoch 10/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8580 - loss: 0.3111 - val_accuracy: 0.7660 - val_loss: 0.5365
# Epoch 11/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8591 - loss: 0.3113 - val_accuracy: 0.7729 - val_loss: 0.5770
# Epoch 12/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8585 - loss: 0.3072 - val_accuracy: 0.7674 - val_loss: 0.5671
# Epoch 13/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8595 - loss: 0.3067 - val_accuracy: 0.7660 - val_loss: 0.5583
# Epoch 14/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8598 - loss: 0.3048 - val_accuracy: 0.7681 - val_loss: 0.5352
# Epoch 15/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8544 - loss: 0.3151 - val_accuracy: 0.7617 - val_loss: 0.5620
# Epoch 16/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8573 - loss: 0.3125 - val_accuracy: 0.7614 - val_loss: 0.5518
# Epoch 17/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8591 - loss: 0.3034 - val_accuracy: 0.7589 - val_loss: 0.5577
# Epoch 18/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8634 - loss: 0.3034 - val_accuracy: 0.7661 - val_loss: 0.5720
# Epoch 19/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8615 - loss: 0.2995 - val_accuracy: 0.7682 - val_loss: 0.5503
# Epoch 20/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8596 - loss: 0.2995 - val_accuracy: 0.7645 - val_loss: 0.5647
# Epoch 21/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8585 - loss: 0.3033 - val_accuracy: 0.7641 - val_loss: 0.5497
# Epoch 22/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8588 - loss: 0.3022 - val_accuracy: 0.7610 - val_loss: 0.5466
# Epoch 23/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8588 - loss: 0.3039 - val_accuracy: 0.7665 - val_loss: 0.5605
# Epoch 24/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8633 - loss: 0.3027 - val_accuracy: 0.7706 - val_loss: 0.5669
# Epoch 25/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8627 - loss: 0.3006 - val_accuracy: 0.7691 - val_loss: 0.5753
# Epoch 26/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8570 - loss: 0.3088 - val_accuracy: 0.7684 - val_loss: 0.5757
# Epoch 27/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8634 - loss: 0.3003 - val_accuracy: 0.7639 - val_loss: 0.5628
# Epoch 28/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8624 - loss: 0.2979 - val_accuracy: 0.7630 - val_loss: 0.5747
# Epoch 29/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8606 - loss: 0.2990 - val_accuracy: 0.7651 - val_loss: 0.5703
# Epoch 30/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8662 - loss: 0.2924 - val_accuracy: 0.7630 - val_loss: 0.5795
# Epoch 31/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8619 - loss: 0.2983 - val_accuracy: 0.7585 - val_loss: 0.5883
# Epoch 32/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8677 - loss: 0.2928 - val_accuracy: 0.7634 - val_loss: 0.5566
# Epoch 33/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8675 - loss: 0.2966 - val_accuracy: 0.7642 - val_loss: 0.5657
# Epoch 34/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8658 - loss: 0.2915 - val_accuracy: 0.7626 - val_loss: 0.5804
# Epoch 35/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8661 - loss: 0.2909 - val_accuracy: 0.7620 - val_loss: 0.5708
# Epoch 36/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8650 - loss: 0.2970 - val_accuracy: 0.7656 - val_loss: 0.6187
# Epoch 37/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8667 - loss: 0.2959 - val_accuracy: 0.7648 - val_loss: 0.5820
# Epoch 38/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8666 - loss: 0.2912 - val_accuracy: 0.7674 - val_loss: 0.5828
# Epoch 39/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8704 - loss: 0.2863 - val_accuracy: 0.7695 - val_loss: 0.5829
# Epoch 40/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8662 - loss: 0.2875 - val_accuracy: 0.7644 - val_loss: 0.6121
# Epoch 41/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8700 - loss: 0.2892 - val_accuracy: 0.7558 - val_loss: 0.5881
# Epoch 42/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8640 - loss: 0.2944 - val_accuracy: 0.7665 - val_loss: 0.5825
# Epoch 43/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8667 - loss: 0.2893 - val_accuracy: 0.7661 - val_loss: 0.5988
# Epoch 44/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8658 - loss: 0.2938 - val_accuracy: 0.7596 - val_loss: 0.5969
# Epoch 45/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8677 - loss: 0.2947 - val_accuracy: 0.7585 - val_loss: 0.5853
# Epoch 46/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8713 - loss: 0.2839 - val_accuracy: 0.7670 - val_loss: 0.5981
# Epoch 47/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8682 - loss: 0.2895 - val_accuracy: 0.7664 - val_loss: 0.5826
# Epoch 48/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8705 - loss: 0.2847 - val_accuracy: 0.7573 - val_loss: 0.6060
# Epoch 49/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8689 - loss: 0.2856 - val_accuracy: 0.7530 - val_loss: 0.6137
# Epoch 50/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8684 - loss: 0.2865 - val_accuracy: 0.7620 - val_loss: 0.5903
# Epoch 51/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8703 - loss: 0.2807 - val_accuracy: 0.7676 - val_loss: 0.6191
# Epoch 52/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8731 - loss: 0.2832 - val_accuracy: 0.7606 - val_loss: 0.6247
# Epoch 53/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8702 - loss: 0.2843 - val_accuracy: 0.7617 - val_loss: 0.6069
# Epoch 54/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8676 - loss: 0.2853 - val_accuracy: 0.7605 - val_loss: 0.5979
# Epoch 55/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8665 - loss: 0.2861 - val_accuracy: 0.7648 - val_loss: 0.6031
# Epoch 56/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8685 - loss: 0.2804 - val_accuracy: 0.7614 - val_loss: 0.5941
# Epoch 57/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8715 - loss: 0.2841 - val_accuracy: 0.7613 - val_loss: 0.5941
# Epoch 58/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8756 - loss: 0.2745 - val_accuracy: 0.7646 - val_loss: 0.6316
# Epoch 59/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8725 - loss: 0.2765 - val_accuracy: 0.7628 - val_loss: 0.5910
# Epoch 60/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8697 - loss: 0.2802 - val_accuracy: 0.7641 - val_loss: 0.6387
# Epoch 61/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8737 - loss: 0.2756 - val_accuracy: 0.7642 - val_loss: 0.6034
# Epoch 62/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8713 - loss: 0.2791 - val_accuracy: 0.7599 - val_loss: 0.6138
# Epoch 63/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8734 - loss: 0.2777 - val_accuracy: 0.7620 - val_loss: 0.6284
# Epoch 64/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8718 - loss: 0.2770 - val_accuracy: 0.7648 - val_loss: 0.6366
# Epoch 65/65
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8750 - loss: 0.2698 - val_accuracy: 0.7523 - val_loss: 0.5597

# %%
# 1️⃣2️⃣ Train Logistic Regression Model for Comparison
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# 1️⃣3️⃣ Train Gradient Boosting Classifier
clf2 = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, subsample=0.8)
clf2.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(subsample=0.8)

# %%
# 1️⃣4️⃣ Predict & Evaluate Performance
y_pred_dl = np.argmax(model.predict(X_test), axis=1)  # Deep Learning Model Predictions
y_pred_lr = clf.predict(X_test)  # Logistic Regression Predictions
y_pred_gb = clf2.predict(X_test)  # Gradient Boosting Predictions
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
print(f"Deep Learning Model Test Accuracy: {accuracy_score(y_test, y_pred_dl):.4f}")
print(f"Logistic Regression Test Accuracy: {accuracy_score(y_test, y_pred_lr):.4f}")
print(f"Gradient Boosting Test Accuracy: {accuracy_score(y_test, y_pred_gb):.4f}")
# Out:
# Deep Learning Model Test Accuracy: 0.7605
# Logistic Regression Test Accuracy: 0.7794
# Gradient Boosting Test Accuracy: 0.7415

# %%
# Training Accuracy for Deep Learning Model
y_train_pred_dl = np.argmax(model.predict(X_train), axis=1)
print(f"Deep Learning Model Train Accuracy: {accuracy_score(y_train, y_train_pred_dl):.4f}")
# Training Accuracy for Logistic Regression
y_train_pred_lr = clf.predict(X_train)
print(f"Logistic Regression Train Accuracy: {accuracy_score(y_train, y_train_pred_lr):.4f}")
# Training Accuracy for Gradient Boosting
y_train_pred_gb = clf2.predict(X_train)
print(f"Gradient Boosting Train Accuracy: {accuracy_score(y_train, y_train_pred_gb):.4f}")
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Deep Learning Model Train Accuracy: 0.8843
# Logistic Regression Train Accuracy: 0.7901
# Gradient Boosting Train Accuracy: 0.7622

# %%
# 1️⃣5️⃣ Save Trained Deep Learning Model
model.save('sentiment_dl_model.h5')  # Save Deep Learning Model
joblib.dump(clf2, 'sentiment_gb_model.pkl')  # Save Gradient Boosting Model
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['sentiment_gb_model.pkl']

# %% [markdown]
# **THE END**

# %%
# Train Logistic Regression Model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_bert, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Evaluate on test set
y_pred = clf.predict(X_test_bert)
print(f"Test Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# Test Accuracy: 0.7787

# %%
# Saving the models
joblib.dump(clf, 'sentiment_model.joblib')  # Save Logistic Regression model
torch.save(model.state_dict(), 'distilbert_model.pth')  # Save BERT model

# %%
# Example predictions
reviews = ['Pure cinematic magic!', 'This film left me speechless', 'Boring, even with explosions.']
test_embeddings = get_bert_embeddings_batch([preprocess(r) for r in reviews], batch_size=16)
predictions = clf.predict(test_embeddings)
print(predictions)  # Display predictions
# Out:
# [1 0 0]

# %%
clf1 = LogisticRegression(max_iter=2000, C=0.5, solver='liblinear')

# %%
clf1.fit(X_train_bert, y_train)
# Out:
# LogisticRegression(C=0.5, max_iter=2000, solver='liblinear')

# %%
# Evaluate on test set
y_pred_1 = clf1.predict(X_test_bert)
print(f"Test Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# Test Accuracy: 0.7787

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf2 = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, subsample= 0.8)

# %%
clf2.fit(X_train_bert, y_train)
# Out:
# GradientBoostingClassifier(subsample=0.8)

# %%
y_pred_2 = clf2.predict(X_test_bert)
print(f"Test Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# Test Accuracy: 0.7787
